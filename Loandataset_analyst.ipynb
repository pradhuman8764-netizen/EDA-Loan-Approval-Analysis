# %% [markdown]
# <a href="https://colab.research.google.com/github/pradhuman8764-netizen/EDA-Loan-Approval-Analysis/blob/main/Loandataset_analyst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/content/loan_data.csv")

# %%
df.shape
# Out:
# (45000, 14)

# %%
df.iloc[1:2]
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 1        21.0        female      High School        12282.0               0
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 1                   OWN     1000.0   EDUCATION          11.14
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 1                 0.08                         2.0           504
#
#   previous_loan_defaults_on_file  loan_status
# 1                            Yes            0

# %%
df.head(1)
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1

# %%
df.info()
#Q1 how many records and columns are present
# here is 14 columns and 45000 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
df.select_dtypes(include = "object").columns
#Q2 columns which are categorical
# Out:
# Index(['person_gender', 'person_education', 'person_home_ownership',
#        'loan_intent', 'previous_loan_defaults_on_file'],
#       dtype='object')

# %%
df.select_dtypes(include = "int").columns
#Q2 columns which are numerical
# Out:
# Index(['person_emp_exp', 'credit_score', 'loan_status'], dtype='object')

# %%
loan_status_data = df['loan_status'].value_counts()
plt.pie(loan_status_data, labels = loan_status_data.index , autopct = "%f1.0%%")

#Q3 the dataset is not balanced between aproved and rejected loan
# the loan regection is 78 percent as compared with the approved loan which is 23 percent
# Out:
# ([<matplotlib.patches.Wedge at 0x7ee668e9e1b0>,
# ...
#  [Text(-0.8426490478933555, 0.7070661794234129, '0'),
#   Text(0.8426491097070433, -0.7070661057566878, '1')],
#  [Text(-0.45962675339637565, 0.3856724615036797, '77.7777791.0%'),
#   Text(0.45962678711293264, -0.38567242132182966, '22.2222231.0%')])

# %%
loan_status_data
# Out:
# loan_status
# 0    35000
# 1    10000
# Name: count, dtype: int64

# %%
dfnull = df.isnull().sum()

# %%
not_null_values = dfnull.value_counts()
plt.pie(not_null_values, labels = not_null_values.index , autopct = "%f1.0%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7ee6953263c0>],
#  [Text(-1.0999999999999959, -9.616505800409723e-08, '0')],
#  [Text(-0.5999999999999978, -5.2453668002234845e-08, '100.0000001.0%')])

# %%
df.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_amnt', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file', 'loan_status'],
#       dtype='object')

# %%
sns.histplot(df['person_income'] , bins = 10 , kde = True , color = "red" , label = "person_income" )
plt.legend()
#Q9 The distribution of income is right skewed
# also as we can see the mean is muchh higher then the median this reflect the distribution is right skewed

mean = df['person_income'].mean()
median = df['person_income'].median()
print("mean = ", mean,"median = " ,median)
# Out:
# mean =  80319.05322222222 median =  67048.0

# %%
person_with_high_income = df['person_income'] > mean
person_with_high_income_by_median = df['person_income'] > median

# %%
person_with_high_income.value_counts()
#here we can see the average person are low on income calclated on the basis of mean income
# Out:
# person_income
# False    28718
# True     16282
# Name: count, dtype: int64

# %%
person_with_high_income_by_median.value_counts()
#Q10 here we can see the 50 percent of the peoples are high on income as per the median of the data and 50% are on low
# Out:
# person_income
# False    22501
# True     22499
# Name: count, dtype: int64

# %%
sns.boxplot(df['person_income'] , color = "red")
# Out:
# <Axes: ylabel='person_income'>

# %%
sns.boxplot(df['loan_amnt'] , color = "red")
#Q11 in both loan amount and person income there are outliers which need to be treated
# Out:
# <Axes: ylabel='loan_amnt'>

# %%
sns.histplot(df['credit_score'] , bins = 10 , kde = True , color = "red" , label = "loan_amnt" )
plt.legend()

#Q12 as per the histogram we can see the distrubution of credit score is nearly evenly distributed

# %%
sns.countplot(df['person_education'] )
#Q13 Associates are the most common peoples applied for loan approx = 12000
#Q14 The most common eduacation level is High School approx = 12000
# Out:
# <Axes: xlabel='count', ylabel='person_education'>

# %%
avg_income_by_loan_status = df.groupby('loan_status')['person_income'].mean()
print("Average income by loan status:")
print(avg_income_by_loan_status)
# Out:
# Average income by loan status:
# loan_status
# 0    86157.040743
# 1    59886.096900
# Name: person_income, dtype: float64

# %%
sns.barplot(x=avg_income_by_loan_status.index, y=avg_income_by_loan_status)
plt.title('Average Person Income by Loan Status')
plt.xlabel('Loan Status (0: Rejected, 1: Approved)')
plt.ylabel('Average Person Income')

#Q15 as per the barplot the person with high income are not getting the loan
# Out:
# Text(0, 0.5, 'Average Person Income')

# %%
loan_Score_data = df.groupby('loan_status')['credit_score'].mean()

# %%
sns.barplot(x=loan_Score_data.index, y=loan_Score_data)
# Out:
# Text(0, 0.5, 'Average Credit Score')

# %%
sns.lineplot(data=df, y='credit_score', x = "loan_status")
# Q16 the minimum credit score where the loan aproval increase sharply is 550 - 600
# Out:
# <Axes: xlabel='loan_status', ylabel='credit_score'>

# %%
loan_status_grouped = df.groupby('loan_status')['loan_amnt'].mean()
print(loan_status_grouped)
# Out:
# loan_status
# 0     9219.576914
# 1    10855.689800
# Name: loan_amnt, dtype: float64

# %%
sns.barplot(x=loan_status_grouped.index, y=loan_status_grouped.values)
plt.title('Average Loan Amount by Loan Status')
plt.xlabel('Loan Status (0: Rejected, 1: Approved)')
plt.ylabel('Average Loan Amount')
#Q17 as per the data the higher loan amount application is approved more ofter
# Out:
# Text(0, 0.5, 'Average Loan Amount')

# %%
piedata = df.groupby(df['person_education'])['loan_status'].mean()

plt.figure(figsize=(5,5))
plt.pie(piedata, labels=piedata.index, autopct="%0.1f%%", startangle=90)
#Q18 the Doctorate Employemnt type has highest approval rate 20.5
#Q19 The education level is not affecting the loan approval as there is very minor difference in approval of all applicants
# Out:
# ([<matplotlib.patches.Wedge at 0x7ee6953178f0>,
# ...
#  [Text(-0.6398490873711824, 0.8947587079153047, 'Associate'),
#   Text(-1.0490823278459156, -0.33079641685090116, 'Bachelor'),
#   Text(0.014983537539793375, -1.0998979469036179, 'Doctorate'),
#   Text(1.0558657747017064, -0.30845982852482684, 'High School'),
#   Text(0.6330295664107926, 0.8995963361695979, 'Master')],
#  [Text(-0.34900859311155397, 0.48805020431743884, '19.8%'),
#   Text(-0.5722267242795902, -0.18043440919140064, '20.2%'),
#   Text(0.008172838658069113, -0.5999443346747005, '20.5%'),
#   Text(0.5759267862009307, -0.16825081555899646, '20.0%'),
#   Text(0.3452888544058868, 0.49068891063796244, '19.5%')])

# %%
numerical_df = df.select_dtypes(exclude = "object")


plt.figure(figsize = (7,7))
sns.heatmap(numerical_df.corr(), annot = True , cmap = "Blues")
#21 The loan_percent_income is highly correlated with loan_amount having (0.59)
# this shows that higher the loan amount significantly increase the loan_percent_income

# 2nd is the person age with higher age the person credit history length also increases (0.86)

#Q22 person income and loan amount //  they are positively correlated, but the relationship is weak.
# Out:
# <Axes: >

# %%
columns_to_exclude = ["loan_percent_income" , "loan_int_rate" , "person_emp_exp" , "cb_person_cred_hist_length"]
small_numerical_df = numerical_df.drop(columns=columns_to_exclude, errors='ignore')

# %%
sns.pairplot(small_numerical_df , hue = "loan_status")

#Q23 As per the pair plot person having high salary but low credit score still get regected
#  we can determine this by the heatmap as the person income and credit score is poorly correlated


#Q24 As per the plot the combination of (higher credit score + low Income ) is more likely to get loan aproved

# %% [markdown]
# Q25 Some more pattern from the insights are
#
# 1. Person having credit score between 550 to 720 approx are likely getting approved loan upto 5000 to 25000
# 2. Person aged over 50 are less applying for loan also not getting loan approved
# 3. here is very less people whose salary is growing as per there age
# 4. Person having less income are applying more loan and also getting loan approved more than the more earning peoples

# %%
sns.boxplot(df['person_income'])
# Out:
# <Axes: ylabel='person_income'>

# %% [markdown]
# Q26 The Box Plot suggests that there are outliers in the dataset of person income which may be data error
# also some people may have high income but for checking this we need to check coorelation with other dataset to determine the outlier

# %% [markdown]
# Q27. Should outliers be capped or removed?
#
# it depends on the data if the outlier frequency is very less then we can remove the outlier
# but if we want to preserve the actual data or dont want to change the dataset we can opt for outlier capping where we can assing the outlier the IQR valur for higher and lower outliers

# %% [markdown]
# Q29 What type of customer gets approved most?
#
# Person with low income and good credit score between 600 to 750
# and loan amount of 5000 to 25000 or asking loan amount less then there loan percent income ratio  are having high chances of getting loan approved

# %% [markdown]
# Q31. Which 3 features influence approval the most?
#
# The 3 features which influence the approval are loan Amount , loan_percent_income_rate and person loan Intrest Rate

# %% [markdown]
# Q32. Can we define a “safe applicant profile”?
#
# We can define an safe applicant profile by looking into some aspects
# 1. The person who is asking for loan amount less then the loan percent income
# 2. The person getting small loan on low intrest rate with good credit history is more likely to repay the loan

# %% [markdown]
# Q33. Can EDA alone help a bank reduce risk?
#
# EDA alone cannot assure 100% risk to be reduced but it will help in future predictiion which will reduce the risk overall
# with the help of EDA we can detect outliers which may reflect as fraud or can see the coorelation between two variables which make the study more insightfull
